# %%
#import dependencies
import pandas as pd

# %%
#import file to dataframe
file_path = r"Assignment_data.xlsx"
df = pd.read_excel(file_path)
df
# Out:
#     ExperimentID ExperimentName ExpDefID SampleType Source  TreatmentNumber  \
# 0          EXP_1           Run1   ED0013    Control  Water                5
# 1          EXP_1           Run1   ED0013    Control  Water                5
# 2          EXP_1           Run1   ED0013    Control  Water                5
# 3          EXP_1           Run1   ED0013    Control  Water                5
# 4          EXP_1           Run1   ED0013    Control  Water                5
# ..           ...            ...      ...        ...    ...              ...
# 145        EXP_6           Run7   ED0013     Sample  Water                3
# 146        EXP_6           Run7   ED0013     Sample  Water                3
# 147        EXP_6           Run7   ED0013     Sample  Water                3
# 148        EXP_6           Run7   ED0013     Sample  Water                3
# 149        EXP_6           Run7   ED0013     Sample  Water                3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ExperimentID     150 non-null    object
#  1   ExperimentName   150 non-null    object
#  2   ExpDefID         150 non-null    object
#  3   SampleType       150 non-null    object
#  4   Source           36 non-null     object
#  5   TreatmentNumber  150 non-null    int64
#  6   SampleID         150 non-null    object
#  7   SequenceID       150 non-null    object
#  8   Concentration    150 non-null    object
#  9   Metric           150 non-null    object
#  10  TimePoint        150 non-null    object
#  11  Value            150 non-null    float64
# dtypes: float64(1), int64(1), object(10)
# memory usage: 14.2+ KB

# %%
# Search for duplicates
duplicates = df[df.duplicated()]
duplicates
# Out:
#     ExperimentID ExperimentName ExpDefID SampleType Source  TreatmentNumber  \
# 126        EXP_5           Run5   ED0013     Sample    NaN                4
# 127        EXP_5           Run5   ED0013     Sample    NaN                4
# 128        EXP_5           Run5   ED0013     Sample    NaN                4
# 129        EXP_5           Run5   ED0013     Sample    NaN                4
# 130        EXP_5           Run5   ED0013     Sample    NaN                4
# 131        EXP_5           Run5   ED0013     Sample    NaN                4
#
#      SampleID SequenceID Concentration             Metric TimePoint  Value
# 126  S0006671      Seq_5  1000.00ng/ul  Percent Mortality     Day_1   0.00
# 127  S0006671      Seq_5  1000.00ng/ul  Percent Mortality     Day_6  31.25
# 128  S0006671      Seq_5  1000.00ng/ul  Percent Mortality     Day_2   6.25
# 129  S0006671      Seq_5  1000.00ng/ul  Percent Mortality     Day_3   6.25
# ...

# %%
# double check data
check = df.loc[(df['ExperimentID'] == "EXP_5") & (df['SampleID'] == "S0006671")]
check
# Out:
#     ExperimentID ExperimentName ExpDefID SampleType Source  TreatmentNumber  \
# 108        EXP_5           Run5   ED0013     Sample    NaN                4
# 109        EXP_5           Run5   ED0013     Sample    NaN                4
# 110        EXP_5           Run5   ED0013     Sample    NaN                4
# 111        EXP_5           Run5   ED0013     Sample    NaN                4
# 112        EXP_5           Run5   ED0013     Sample    NaN                4
# 113        EXP_5           Run5   ED0013     Sample    NaN                4
# 126        EXP_5           Run5   ED0013     Sample    NaN                4
# 127        EXP_5           Run5   ED0013     Sample    NaN                4
# 128        EXP_5           Run5   ED0013     Sample    NaN                4
# 129        EXP_5           Run5   ED0013     Sample    NaN                4
# 130        EXP_5           Run5   ED0013     Sample    NaN                4
# ...

# %%
# drop duplicates
cleaned_df = df.drop_duplicates()
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 144 entries, 0 to 149
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ExperimentID     144 non-null    object
#  1   ExperimentName   144 non-null    object
#  2   ExpDefID         144 non-null    object
#  3   SampleType       144 non-null    object
#  4   Source           36 non-null     object
#  5   TreatmentNumber  144 non-null    int64
#  6   SampleID         144 non-null    object
#  7   SequenceID       144 non-null    object
#  8   Concentration    144 non-null    object
#  9   Metric           144 non-null    object
#  10  TimePoint        144 non-null    object
#  11  Value            144 non-null    float64
# dtypes: float64(1), int64(1), object(10)
# memory usage: 14.6+ KB

# %%
# Save cleaned df to file
cleaned_df.to_excel('Assignment_data_cleaned.xlsx')
